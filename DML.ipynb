# %%
import os
os.chdir('/content/drive/MyDrive/pytorch/DML')
os.getcwd()
# Out:
# '/content/drive/MyDrive/pytorch/DML'

# %%
# !git clone 'https://github.com/pilsHan/DML_for-personal-study.git'

# %%
# !python /content/drive/MyDrive/pytorch/DML/DML_for-personal-study/main.py
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# 100% 782/782 [00:44<00:00, 17.62it/s]
# [EPOCH : 1] net1 Loss: 3.7746, net1 Accuracy: 6.56%
#  train net2 Loss: 3.7454, net2 Accuracy: 6.75%
# [EPOCH : 1] net1 Loss: 3.9793, net1 Accuracy: 10.08%
#  test  net2 Loss: 3.7883, net2 Accuracy: 11.41%
# 100% 782/782 [00:44<00:00, 17.52it/s]
# [EPOCH : 2] net1 Loss: 3.8970, net1 Accuracy: 15.66%
#  train net2 Loss: 4.1279, net2 Accuracy: 15.75%
# ...

# %%
# !python /content/drive/MyDrive/pytorch/DML/DML_for-personal-study/independent.py
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# 100% 782/782 [00:22<00:00, 35.12it/s]
# [1] Train Loss: 0.0641, Accuracy: 6.11%
# [1] Test Loss: 0.0589, Accuracy: 10.51%
# 100% 782/782 [00:21<00:00, 35.76it/s]
# [2] Train Loss: 0.0558, Accuracy: 14.04%
# [2] Test Loss: 0.0541, Accuracy: 16.59%
# 100% 782/782 [00:22<00:00, 35.52it/s]
# [3] Train Loss: 0.0494, Accuracy: 21.45%
# [3] Test Loss: 0.0493, Accuracy: 21.49%
# ...

# %%
# !python /content/drive/MyDrive/pytorch/DML/DML_for-personal-study/main.py --net2 WRN_28_10
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# 100% 782/782 [05:25<00:00,  2.41it/s]
# [EPOCH : 1] net1 Loss: 3.6709, net1 Accuracy: 7.77%
#  train net2 Loss: 3.5475, net2 Accuracy: 9.13%
# [EPOCH : 1] net1 Loss: 3.8598, net1 Accuracy: 11.02%
#  test  net2 Loss: 3.6580, net2 Accuracy: 14.56%
# 100% 782/782 [05:25<00:00,  2.41it/s]
# [EPOCH : 2] net1 Loss: 3.6024, net1 Accuracy: 18.65%
#  train net2 Loss: 3.4798, net2 Accuracy: 21.23%
# ...

# %%
# !python /content/drive/MyDrive/pytorch/DML/DML_for-personal-study/independent.py --independent WRN_28_10
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# 100% 782/782 [09:02<00:00,  1.44it/s]
# [1] Train Loss: 0.0620, Accuracy: 8.61%
# [1] Test Loss: 0.0565, Accuracy: 13.28%
# 100% 782/782 [09:06<00:00,  1.43it/s]
# [2] Train Loss: 0.0515, Accuracy: 18.91%
# [2] Test Loss: 0.0470, Accuracy: 24.52%
# 100% 782/782 [09:05<00:00,  1.43it/s]
# [3] Train Loss: 0.0432, Accuracy: 28.34%
# [3] Test Loss: 0.0438, Accuracy: 27.67%
# ...
